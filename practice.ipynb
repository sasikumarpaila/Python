# %%
print("Hello World")
# Out:
# Hello World

# %%
num = 2
print(num)
# Out:
# 2

# %%
nums = [3,4,6,7,8]
print(nums)
# Out:
# [3, 4, 6, 7, 8]

# %%
nums[1:3]
# Out:
# [4, 6]

# %%
names = ['ravi', 'sai', 'kumar']
print(names)
# Out:
# ['ravi', 'sai', 'kumar']

# %%
mix = [1,2,'sai']
print(mix)
# Out:
# [1, 2, 'sai']

# %%
print(nums,names)
# Out:
# [3, 4, 6, 7, 8] ['ravi', 'sai', 'kumar']

# %%
mix[1]
# Out:
# 2

# %%
nums.append(22)
print(nums)
# Out:
# [3, 4, 6, 7, 8, 22]

# %%
nums.insert(1,22)
print(nums)
# Out:
# [3, 22, 4, 6, 7, 8, 22]

# %%
nums.remove(22)
print(nums)
# Out:
# [3, 4, 6, 7, 8, 22]

# %%
nums.pop(2)
print(nums)
# Out:
# [3, 4, 7, 8, 22]

# %%
a=[33,76,24,56]
b=['ravi','kumar','sai']
print((a[:2]+b[1:])[-3])
# Out:
# 76

# %%
tup = [22,34,55]
type(tup)
# Out:
# list

# %%
tup = 22,23,24
type(tup)
# Out:
# tuple

# %%
tup = (2,4,6,9)
type(tup)
# Out:
# tuple

# %%
min(tup)
# Out:
# 2

# %%
tup[2]
# Out:
# 6

# %%
tupA = (2,'sai',7.9)
tupA
# Out:
# (2, 'sai', 7.9)

# %%
num, name, num1 = tupA
num
# Out:
# 2

# %%
name
# Out:
# 'sai'

# %%
num1
# Out:
# 7.9

# %%
tupB = (2,'sai',[1,2,4,6])
tupB[2][1] = 9
tupB
# Out:
# (2, 'sai', [1, 9, 4, 6])

# %%
tup = (50,70,90)
x = tup[0]
y = tup[2]
print(x + y)
# Out:
# 140

# %%
set1 = {22,24,45,33}
set1
# Out:
# {22, 24, 33, 45}

# %%
set2 = {}
type(set2)
# Out:
# dict

# %%
type(set1)
# Out:
# set

# %%
data = {0:34,1:35,2:67,3:8}
data[2]
# Out:
# 67

# %%
data ={'kiran':34,'ravi':33}
data['kiran']
# Out:
# 34

# %%
data.get('kiran')
# Out:
# 34

# %%
data = {
    'sai': ['play','eat'],
    'kiran': {'forntend': 'React', 'backend':'Spring'},
}

print(data['kiran']['backend'])
# Out:
# Spring

# %%
a='sai'
b='sai'
print(id(a) == id(b))
# Out:
# True

# %%
a=2
b=3
c=complex(a,b)
c
# Out:
# (2+3j)

# %%
ls = [4,5,6]
tup = (7,8)
x = list(tup)
print(x)
# Out:
# [7, 8]

# %%
a=3
b=4

a*= 2
b -= a

print(a>b and b>0)
# Out:
# False
